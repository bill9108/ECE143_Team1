# %%
import pandas as pd
import json
import numpy as np
import math
from matplotlib import pyplot as plt
import itertools as it

# %%
import json

data = []
with open('./yelp_academic_dataset_user.json',encoding="utf8") as f:
    for line in f:
        data.append(json.loads(line))

# %%
avg_stars = []
for i in range(len(data)):
    avg_stars.append(data[i]['average_stars'])
# average stars has the data of average stars each user rate

# %%
review_count = []
for i in range(len(data)):
    review_count.append(data[i]['review_count'])
# review_count has the data of the number of reviews of each yelp user

# %%
num_friend = []
for i in range(len(data)):
    friendlist = data[i]['friends'].split(', ')
    num_friend.append(len(friendlist))
# num_friend has the data of the number of friends each user had on their Yelp account

# %%
text_list = [0]*10

for i in review_count:
    if i in range(0,31):
        text_list[0] +=1
    elif i in range(31,61):
        text_list[1] +=1
    elif i in range(61,91):
        text_list[2] +=1
    elif i in range(91,121):
        text_list[3] +=1
    elif i in range(121,151):
        text_list[4] +=1
    elif i in range(151,181):
        text_list[5] +=1
    elif i in range(181,211):
        text_list[6] +=1
    elif i in range(211,241):
        text_list[7] +=1
    elif i in range(241,271):
        text_list[8] +=1
    elif i in range(271,301):
        text_list[9] +=1
print(text_list)
# Out:
# [1688399, 134501, 50260, 26518, 16591, 11073, 8121, 5916, 4482, 3428]

# %%
data = review_count

bins = np.linspace(0, 300,11)

plt.figure(num=None, figsize=(12, 4), dpi=80)
arr=plt.hist(data, bins=bins, alpha = 0.8)
for i in range(10):
    plt.text(arr[1][i],arr[0][i],str(arr[0][i]))
plt.title('distribution on the number of reviews users made')
plt.xlabel('Interval of the number of reviews users made')
plt.ylabel('count')
plt.close()
review_value=[]
for i in range(10):
    review_value.append(arr[0][i])

# %%
xaxes=['0-30','30-60','60-90','90-120','120-150','150-180','180-210','210-240','240-270','270-300']

plt.figure(num=None, figsize=(12, 8), dpi=80)
barlist = plt.bar (xaxes, review_value,color='b')
for i, v in enumerate(review_value):
    plt.text(i, v + 25, str(v), color='red', fontweight='bold', ha='center')
plt.title('distribution on the number of reviews users made',fontsize=20)
plt.xlabel('Interval of the number of reviews users made',fontsize=15)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
rest = 0
for i in range(3,10):
    rest += arr[0][i] 
labels = 'under 30','30-60','60-90','other'
sizes = [arr[0][0],arr[0][1],arr[0][2],rest]
explode = (0.05,0.05,0,0)
fig1, ax1 = plt.subplots(figsize=(10,10))

patches, texts, autotexts = ax1.pie(sizes, explode=explode,labels = labels, autopct = '%1.2f%%',shadow=True, startangle = 45)
ax1.axis('equal')
for t in texts:
    t.set_fontsize(14)
for at in autotexts:
    at.set_fontsize(14)
    at.set_color('white')
    at.set_fontweight('bold')
plt.title('percentage on the number of reviews users made',fontsize=20)
plt.show()

# %%
new_bins = np.linspace(0,60,16)
plt.figure(num=None, figsize=(18, 6), dpi=80)
arr2= plt.hist(data, bins=new_bins,alpha=0.8)
for i in range(15):
    plt.text(arr2[1][i],arr2[0][i],str(arr2[0][i]))
plt.title('distribution on the number of reviews below 60')
plt.xlabel('Interval of the number of reviews users made')
plt.ylabel('count')
plt.close()

review_value_60=[]
for i in range(15):
    review_value_60.append(arr2[0][i])

# %%
xaxes=['0-4','4-8','8-12','12-16','16-20','20-24','24-28','28-32','32-36','36-40','40-44','44-48','48-52','52-56','56-60']

plt.figure(num=None, figsize=(12, 8), dpi=80)
barlist = plt.bar (xaxes, review_value_60,color='b')
for i, v in enumerate(review_value_60):
    plt.text(i, v + 25, str(v), color='red', fontweight='bold', ha='center')
plt.title('distribution on the number of reviews below 60',fontsize=20)
plt.xlabel('Interval of the number of reviews users made',fontsize=15)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
rest2 = 0
for i in range(4,15):
    rest2 += arr2[0][i] 
labels = 'under 6','6-12','12-18','18-24','above24'
sizes = [arr2[0][0],arr2[0][1],arr2[0][2],arr2[0][3],rest2]
explode = (0.05,0.05,0,0,0)
fig1, ax1 = plt.subplots(figsize=(10,10))

patches, texts, autotexts = ax1.pie(sizes, explode=explode,labels = labels, autopct = '%1.2f%%',shadow=True, startangle = 45)
ax1.axis('equal')
for t in texts:
    t.set_fontsize(14)
for at in autotexts:
    at.set_fontsize(14)
    at.set_color('white')
    at.set_fontweight('bold')
plt.title('percentage on the number of reviews users made under 60 reviews',fontsize=20)
plt.show()

# %%
star_data = avg_stars

bins = np.linspace(1,5,9)

plt.figure(num=None, figsize=(12, 6), dpi=80)
arr3=plt.hist(star_data, bins=bins, alpha = 0.8)
for i in range(8):
    plt.text(arr3[1][i],arr3[0][i],str(arr3[0][i]))
plt.title('Average stars users rated')
plt.xlabel('Interval of the average stars users rated')
plt.ylabel('count')
plt.close()

star_count=[]
for i in range(8):
    star_count.append(arr3[0][i])

# %%
xaxes=['1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5']

plt.figure(num=None, figsize=(12, 8), dpi=80)
barlist = plt.bar (xaxes, star_count,color='b')
for i, v in enumerate(star_count):
    plt.text(i, v + 25, str(v), color='red', fontweight='bold', ha='center')
plt.title('distribution on the average stars users rated',fontsize=20)
plt.xlabel('Interval of the average stars users rated',fontsize=15)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
 labels = '1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5'
sizes = [arr3[0][0],arr3[0][1],arr3[0][2],arr3[0][3],arr3[0][4],arr3[0][5],arr3[0][6],arr3[0][7]]

fig1, ax1 = plt.subplots(figsize=(10,10))

patches, texts, autotexts = ax1.pie(sizes,labels = labels, autopct = '%1.2f%%',shadow=True, startangle = 90)
ax1.axis('equal')
for t in texts:
    t.set_fontsize(14)
for at in autotexts:
    at.set_fontsize(14)
    at.set_color('white')
    at.set_fontweight('bold')
plt.title('percentage on the average stars users rated',fontsize=20)
plt.show()

# %%
pair=[]
for i in range(len(avg_stars)):
    pair.append((review_count[i],avg_stars[i]))
len(pair)
# Out:
# 1968703

# %%
stat_30 = [0]*8
stat_60 = [0]*8
stat_g60 = [0]*8
for i in pair:
    if (i[1]>=1 and i[1] <1.5) and int(i[0]) <30:
        stat_30[0]+=1
    elif (i[1]>=1 and i[1] <1.5) and (i[0] >=30 and i[0] <=60):
        stat_60[0]+=1
    elif (i[1]>=1 and i[1] <1.5) and i[0] >60:
        stat_g60[0]+=1
    elif (i[1]>=1.5 and i[1] <2) and i[0] <30:
        stat_30[1]+=1
    elif (i[1]>=1.5 and i[1] <2) and (i[0] >=30 and i[0] <=60):
        stat_60[1]+=1
    elif (i[1]>=1.5 and i[1] <2) and i[0] >60:
        stat_g60[1]+=1
    elif (i[1]>=2.0 and i[1] <2.5) and i[0] <30:
        stat_30[2]+=1
    elif (i[1]>=2.0 and i[1] <2.5) and (i[0] >=30 and i[0] <=60):
        stat_60[2]+=1
    elif (i[1]>=2.0 and i[1] <2.5) and i[0] >60:
        stat_g60[2]+=1
    elif (i[1]>=2.5 and i[1] <3.0) and i[0] <30:
        stat_30[3]+=1
    elif (i[1]>=2.5 and i[1] <3.0) and (i[0] >=30 and i[0] <=60):
        stat_60[3]+=1
    elif (i[1]>=2.5 and i[1] <3.0) and i[0] >60:
        stat_g60[3]+=1
    elif (i[1]>=3.0 and i[1] <3.5) and i[0] <30:
        stat_30[4]+=1
    elif (i[1]>=3.0 and i[1] <3.5) and (i[0] >=30 and i[0] <=60):
        stat_60[4]+=1
    elif (i[1]>=3.0 and i[1] <3.5) and i[0] >60:
        stat_g60[4]+=1
    elif (i[1]>=3.5 and i[1] <4.0) and i[0] <30:
        stat_30[5]+=1
    elif (i[1]>=3.5 and i[1] <4.0) and (i[0] >=30 and i[0] <=60):
        stat_60[5]+=1
    elif (i[1]>=3.5 and i[1] <4.0) and i[0] >60:
        stat_g60[5]+=1
    elif (i[1]>=4.0 and i[1] <4.5) and i[0] <30:
        stat_30[6]+=1
    elif (i[1]>=4.0 and i[1] <4.5) and (i[0] >=30 and i[0] <=60):
        stat_60[6]+=1
    elif (i[1]>=4.0 and i[1] <4.5) and i[0] >60:
        stat_g60[6]+=1
    elif (i[1]>=4.5 and i[1] <=5.0) and i[0] <30:
        stat_30[7]+=1
    elif (i[1]>=4.5 and i[1] <=5.0) and (i[0] >=30 and i[0] <=60):
        stat_60[7]+=1
    elif (i[1]>=4.5 and i[1] <=5.0) and i[0] >60:
        stat_g60[7]+=1

# %%
sum(stat_30)+sum(stat_60)+sum(stat_g60)
# Out:
# 1968703

# %%
stat_g60
# Out:
# [32, 237, 1098, 5327, 23877, 65467, 43312, 6453]

# %%
bars = np.add(stat_30,stat_60).tolist()
labels = ['1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5']
fig, ax = plt.subplots(figsize=(12,15))
ax.bar(labels,stat_30,color = 'g',label='users who write under 30 reviews')
ax.bar(labels,stat_60,color = 'r',bottom = stat_30,label='users who write 30 to 60 reviews')
ax.bar(labels,stat_g60,color = 'b',bottom = bars,label = 'users who write more than 60 reviews')
plt.title('Relationship between average stars users rated and the number of reviews they made')
plt.xlabel('Interval of the average stars users rated')
plt.ylabel('total count')
plt.legend(prop={'size':15})
plt.show()

# %%
bars = np.add(stat_30,stat_60).tolist()
labels = ['1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5']
fig, ax = plt.subplots(figsize=(12,15))
ax.bar(labels,stat_60,color = 'r',label='users who write 30 to 60 reviews')
ax.bar(labels,stat_g60,color = 'b',bottom = stat_60,label = 'users who write more than 60 reviews')
plt.legend(prop={'size':15})
plt.title('Relationship between average stars users rated and the number of reviews they made excluding the users who made less than 30 reviews')
plt.xlabel('Interval of the average stars users rated')
plt.ylabel('total count')
plt.show()

# %%
bins = np.linspace(0, 500,11)

plt.figure(num=None, figsize=(12, 6), dpi=80)
arr4=plt.hist(num_friend, bins=bins, alpha = 0.8)
for i in range(10):
    plt.text(arr4[1][i],arr4[0][i],str(arr4[0][i]))
plt.title('distribution on the total number of friends users had on Yelp')
plt.xlabel('Interval of the number of friends users had')
plt.ylabel('count')
plt.close()

friend_data=[]
for i in range(10):
    friend_data.append(arr4[0][i])

# %%
xaxes=['0-50','50-100','100-150','150-200','200-250','250-300','300-350','350-400','400-450','450-500']

plt.figure(num=None, figsize=(12, 8), dpi=80)
barlist = plt.bar (xaxes, friend_data,color='b')
for i, v in enumerate(friend_data):
    plt.text(i, v + 25, str(v), color='red', fontweight='bold', ha='center')
plt.title('distribution on the total number of friends users had on Yelp',fontsize=20)
plt.xlabel('Interval of the number of friends users had',fontsize=15)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
bins = np.linspace(1, 10,10)

plt.figure(num=None, figsize=(12, 6), dpi=80)
arr5=plt.hist(num_friend, bins=bins, alpha = 0.8)
for i in range(9):
    plt.text(arr5[1][i],arr5[0][i],str(arr5[0][i]))
plt.title('distribution on the total number of friends users had on Yelp (capped within 10)')
plt.xlabel('Interval of the number of friends users had')
plt.ylabel('count')
plt.close()

friend_data_within10=[]
for i in range(9):
    friend_data_within10.append(arr5[0][i])

# %%
xaxes=['1','2','3','4','5','6','7','8','9']

plt.figure(num=None, figsize=(12, 8), dpi=80)
barlist = plt.bar (xaxes, friend_data_within10,color='b')
for i, v in enumerate(friend_data_within10):
    plt.text(i, v + 25, str(v), color='red', fontweight='bold', ha='center')
plt.title('distribution on the total number of friends users had on Yelp (capped within 10)',fontsize=20)
plt.xlabel('Interval of the number of friends users had',fontsize=15)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
percent = (952382/len(num_friend))*100

# %%
print('the percentage that users have only one friend on Yelp is '+ "{:.2f}".format(percent))
# Out:
# the percentage that users have only one friend on Yelp is 48.38

# %%
sizes = [952382,len(num_friend)-952382]
explode = (0.02,0)
labels = 'users that have only one friend','users that have more than one friend'
fig1, ax1 = plt.subplots(figsize=(10,10))

patches, texts, autotexts = ax1.pie(sizes, explode=explode,labels = labels, autopct = '%1.2f%%',shadow=True, startangle = 45)
ax1.axis('equal')
for t in texts:
    t.set_fontsize(14)
for at in autotexts:
    at.set_fontsize(14)
    at.set_color('white')
    at.set_fontweight('bold')
plt.title('percentage of users that have only one friend VS percentage of users that have more than one friend',fontsize=20)
plt.show()

# %%
pair2=[]
for i in range(len(avg_stars)):
    pair2.append((review_count[i],num_friend[i]))
len(pair2)
# Out:
# 1968703

# %%
pair2[2]
# Out:
# (60, 35)

# %%
review_one = [0]*6
review_more = [0]*6
for i in pair2:
    if i[0] < 10 and i[1]==1:
        review_one[0]+=1
    elif i[0] <10 and i[1]>1:
        review_more[0]+=1
    elif (i[0]>=10 and i[0]<20) and i[1]==1:
        review_one[1]+=1
    elif (i[0]>=10 and i[0]<20) and i[1]>1:
        review_more[1]+=1
    elif (i[0]>=20 and i[0]<30) and i[1]==1:
        review_one[2]+=1
    elif (i[0]>=20 and i[0]<30) and i[1]>1:
        review_more[2]+=1
    elif (i[0]>=30 and i[0]<40) and i[1]==1:
        review_one[3]+=1
    elif (i[0]>=30 and i[0]<40) and i[1]>1:
        review_more[3]+=1
    elif (i[0]>=40 and i[0]<50) and i[1]==1:
        review_one[4]+=1
    elif (i[0]>=40 and i[0]<50) and i[1]>1:
        review_more[4]+=1
    elif i[0]>=50 and i[1]==1:
        review_one[5]+=1
    elif i[0]>=50 and i[1]>1:
        review_more[5]+=1

# %%
sum(review_one)+sum(review_more)
# Out:
# 1968703

# %%
labels = ['less than 10 reviews','10-20 reviews','20-30 reviews','30-40 reviews','40-50 reviews','more than 50 reviews']
fig, ax = plt.subplots(figsize=(12,15))
ax.bar(labels,review_more,color = 'r',label='users who only have one friend on Yelp')
ax.bar(labels,review_one,color = 'b',bottom = review_more,label = 'users who have more than one friend on Yelp')
plt.legend(prop={'size':15})
plt.title('Relationship between the number of reviews users made and the number of friends they have on Yelp')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## An interesting point is that, users who only have one friend on Yelp tend to make more reviews than users who have many friends on Yelp
