# %%
import matplotlib.pyplot as plt
import pandas as pd
from textblob import TextBlob
import progressbar
import plotly.graph_objs as go
import numpy as np
import plotly as py
import cufflinks
from wordcloud import WordCloud, STOPWORDS
from plotly.offline import init_notebook_mode,iplot
import re
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
business=pd.read_json('E:\Yelp_dataset_business_clean.json')

# %%
business=business.dropna(subset=['categories'])
business
restaurant=business[business['categories'].str.contains('Restaurants')]

# %%
labels=['ON','AZ','NV','QC','OH','NC','PA','AB','WI']
good=restaurant[restaurant['stars']>=4]['state'].value_counts()
size1=[]
for i in range(len(good)):
    p=good.iloc[i]/sum(good.values)
    if p>0.01:
        size1.append(p*100)
#explode=(0.1,0.1,0,0,0,0,0,0,0)

# %%
bad=restaurant[restaurant['stars']<=2]['state'].value_counts()
size2=[]
for i in range(len(bad)):
    p=bad.iloc[i]/sum(bad.values)
    if p>0.01:
        size2.append(p*100)
size2.pop()
# Out:
# 1.5189873417721518

# %%
medium=restaurant[restaurant['stars']==3]['state'].value_counts()
size3=[]
for i in range(len(medium)):
    p=medium.iloc[i]/sum(medium.values)
    if p>0.01:
        size3.append(p*100)
size3.pop()
# Out:
# 1.4310747663551402

# %%
fig = go.Figure(data=[go.Bar(name='good',x=labels, y=size1),go.Bar(name='medium',x=labels,y=size3),go.Bar(name='bad',x=labels,y=size2)])
fig.update_layout(barmode='group',title='top9 restaurant with different star rate')
fig
# Out:
# <div>                            <div id="3d6e2517-763f-45ae-8be8-783d07e25a97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d6e2517-763f-45ae-8be8-783d07e25a97")) {                    Plotly.newPlot(                        "3d6e2517-763f-45ae-8be8-783d07e25a97",                        [{"name": "good", "type": "bar", "x": ["ON", "AZ", "NV", "QC", "OH", "NC", "PA", "AB", "WI"], "y": [31.429724548481484, 22.459893048128343, 15.386943799818384, 11.81515487841792, 11.76470588235294, 4.782564826959944, 1.4125718898193926]}, {"name": "medium", "type": "bar", "x": ["ON", "AZ", "NV", "QC", "OH", "NC", "PA", "AB", "WI"], "y": [31.133177570093455, 19.772196261682243, 15.800233644859812, 12.733644859813085, 11.623831775700936, 5.169392523364486, 2.2488317757009346]}, {"name": "bad", "type": "bar", "x": ["ON", "AZ", "NV", "QC", "OH", "NC", "PA", "AB", "WI"], "y": [33.164556962025316, 19.029535864978904, 17.046413502109704, 14.810126582278482, 8.734177215189872, 3.459915611814346, 1.8565400843881856]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"] ...

# %%
fig = go.Figure(data=[go.Pie(labels=labels, values=size1,textinfo='label+percent')])
fig.update_layout(title='top 9 good restaurants: star>=4')
fig
# Out:
# <div>                            <div id="69168c8c-8302-48ca-9e82-99e9761895aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69168c8c-8302-48ca-9e82-99e9761895aa")) {                    Plotly.newPlot(                        "69168c8c-8302-48ca-9e82-99e9761895aa",                        [{"labels": ["ON", "AZ", "NV", "QC", "OH", "NC", "PA", "AB", "WI"], "textinfo": "label+percent", "type": "pie", "values": [31.429724548481484, 22.459893048128343, 15.386943799818384, 11.81515487841792, 11.76470588235294, 4.782564826959944, 1.4125718898193926]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{ ...

# %%
fig = go.Figure(data=[go.Pie(labels=labels, values=size3,textinfo='label+percent')])
fig.update_layout(title='top 9 good restaurants: star=3')
fig
# Out:
# <div>                            <div id="47f31181-dd92-4591-bf7c-5f8443759261" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47f31181-dd92-4591-bf7c-5f8443759261")) {                    Plotly.newPlot(                        "47f31181-dd92-4591-bf7c-5f8443759261",                        [{"labels": ["ON", "AZ", "NV", "QC", "OH", "NC", "PA", "AB", "WI"], "textinfo": "label+percent", "type": "pie", "values": [31.133177570093455, 19.772196261682243, 15.800233644859812, 12.733644859813085, 11.623831775700936, 5.169392523364486, 2.2488317757009346]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d":  ...

# %%
fig = go.Figure(data=[go.Pie(labels=labels, values=size2,textinfo='label+percent')])
fig.update_layout(title='top 9 good restaurants: star<=2')
fig
# Out:
# <div>                            <div id="9e60d0b8-ea40-4054-9c88-88581f4c7651" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e60d0b8-ea40-4054-9c88-88581f4c7651")) {                    Plotly.newPlot(                        "9e60d0b8-ea40-4054-9c88-88581f4c7651",                        [{"labels": ["ON", "AZ", "NV", "QC", "OH", "NC", "PA", "AB", "WI"], "textinfo": "label+percent", "type": "pie", "values": [33.164556962025316, 19.029535864978904, 17.046413502109704, 14.810126582278482, 8.734177215189872, 3.459915611814346, 1.8565400843881856]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [ ...

# %%
review=pd.read_json('Yelp_dataset_review_clean.json')

# %%
review['user_id'].unique()
# Out:
# array(['4PFwh5zbgyPhTGRtxkSZZA', 'dvwFC5u09dbG_16AeNKBmQ',
#        'Z6-ZsBP3DqfQNt2Xju6epA', ..., 'KEUHEu0zR6kEH89P_Wlbhw',
#        'zv51SeKf36N2jU84UFPCkw', 'pjj4Y76C7jHNpH4WOG6slQ'], dtype=object)

# %%
rest_5=restaurant[restaurant['stars']==4]
rest_5
# Out:
#                    business_id                          name  \
# 33      vjTVxnsQEZ34XjYNS-XUpA             Wetzel's Pretzels
# 63      ZkzutF0P_u0C0yTulwaHkA              Lelulos Pizzeria
# 115     8Hvp1tYKiQbBgGIwkCRK5g      Tony's Family Restaurant
# 129     OGVHlFHSXjHuioOvm1wVqg  The Jackman Bar & Restaurant
# 157     Yr_w9lakJrKMyEG_hI6zbA       Fat Moe's Pizza & Wings
# ...                        ...                           ...
# 209277  qWcaGio9JsqrvgmQiIRtIQ           Country Style Pizza
# 209281  8WIcKHx7of-pyj2C3CyuIg                     Five Guys
# 209317  tv-WIUQifcp5J9pUKoiE3Q                 Dragon Grille
# 209344  kPwYdRKp1-W1-tUR8iylxw              Aladdin's Eatery
# 209376  cmsAFAymfVoBitSF8R6GKw      Yao Fine Chinese Cuisine
#
#                              address           city state postal_code  \
# 33      4550 East Cactus Rd, #KSFC-4        Phoenix    AZ       85032
# 63               311 Unity Center Rd           Plum    PA       15239
# 115        1515 W Pleasant Valley Rd          Parma    OH       44134
# 129                  918 Jackman Ave         Avalon    PA       15202
# 157      6125 W Tropicana Ave, Ste F      Las Vegas    NV       89103
# ...                              ...            ...   ...         ...
# 209277                 536 Dewey Ave    Bridgeville    PA       15017
# 209281                9826 Gilead Rd   Huntersville    NC       28078
# 209317                                    Las Vegas    NV       89119
# 209344              4885 McKnight Rd  Ross Township    PA       15237
# 209376    2487 S Gilbert Rd, Ste 102        Gilbert    AZ       85295
#
#          latitude   longitude  stars  review_count  \
# 33      33.602822 -111.983533    4.0            10
# 63      40.489996  -79.779288    4.0            31
# 115     41.361185  -81.688755    4.0            60
# 129     40.496381  -80.065479    4.0            13
# 157     36.099361 -115.226636    4.0           141
# ...           ...         ...    ...           ...
# 209277  40.356300  -80.110600    4.0            39
# 209281  35.406267  -80.864353    4.0            31
# 209317  36.076518 -115.153343    4.0            69
# 209344  40.530338  -80.010495    4.0            94
# 209376  33.304935 -111.788861    4.0           230
#
#                                                attributes  \
# 33      {'GoodForKids': 'True', 'RestaurantsTakeOut': ...
# 63      {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 115     {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 129     {'BusinessParking': '{'garage': False, 'street...
# 157     {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# ...                                                   ...
# 209277  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 209281  {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 209317  {'GoodForKids': 'True', 'Alcohol': 'u'none'', ...
# 209344  {'HasTV': 'False', 'RestaurantsPriceRange2': '...
# 209376  {'RestaurantsGoodForGroups': 'True', 'Ambience...
#
#                                                categories  \
# 33       Food, Pretzels, Bakeries, Fast Food, Restaurants
# 63                                     Restaurants, Pizza
# 115     Coffee & Tea, Restaurants, Food, Breakfast & B...
# 129     Dive Bars, Restaurants, Comfort Food, Bars, Ni...
# 157                    Pizza, Salad, Burgers, Restaurants
# ...                                                   ...
# 209277     Food, Restaurants, Bakeries, Pizza, Sandwiches
# 209281  Fast Food, Buffets, Restaurants, American (New...
# 209317       Food, Asian Fusion, Food Trucks, Restaurants
# 209344  Juice Bars & Smoothies, Mediterranean, Restaur...
# 209376                               Chinese, Restaurants
#
#                                                     hours
# 33      {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 63      {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 115     {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
# 129     {'Monday': '11:30-2:0', 'Tuesday': '11:30-2:0'...
# 157     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# ...                                                   ...
# 209277  {'Monday': '0:0-0:0', 'Tuesday': '9:0-21:0', '...
# 209281  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209317  {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# 209344  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 209376  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
#
# [5929 rows x 13 columns]

# %%
a=list(set(rest_5['business_id']))
a[0]
# Out:
# 'GVVf7BZ-4HiuKKbHaFTBsg'

# %%
b=list(review[review['business_id']==a[10]]['text'])

# %%
star=[1, 2, 3, 4, 5]
fig=go.Figure()
avg_polarity=[]
for i in range(len(star)):    
    rest_5=restaurant[restaurant['stars']==star[i]]
    a=list(set(rest_5['business_id']))
    hh=[]
    for j in progressbar.progressbar(range(len(a))):
        b=list(review[review['business_id']==a[j]]['text'])
        polarity=[]
        for sentence in b:
            blob = TextBlob(sentence)
            polarity.append(blob.sentiment.polarity)
        if len(polarity)!=0:
            hh.append(sum(polarity)/len(polarity))
    avg_polarity.append(sum(hh)/len(hh))
    print(avg_polarity)
    trace=go.Scatter(x=np.linspace(0,len(hh),num=len(hh)),y=hh,line_shape='spline',name='star{}'.format(str(star[i])))
    fig.add_trace(trace)
    fig.update_layout(title="polarity of different star rate",xaxis_title='review number',yaxis_title='Polarity')
fig
# Out:
# 100% (146 of 146) |######################| Elapsed Time: 0:00:23 Time:  0:00:23
862068965517, 111.76551724137931, 112.77241379310345, 113.77931034482759, 114.78620689655173, 115.79310344827586, 116.8, 117.80689655172414, 118.81379310344828, 119.82068965517242, 120.82758620689656, 121.8344827586207, 122.84137931034483, 123.84827586206897, 124.8551724137931, 125.86206896551724, 126.86896551724138, 127.87586206896552, 128.88275862068966, 129.8896551724138, 130.89655172413794, 131.90344827586208, 132.91034482758621, 133.91724137931035, 134.9241379310345, 135.93103448275863, 136.93793103448277, 137.9448275862069, 138.95172413793102, 139.95862068965516, 140.9655172413793, 141.97241379310344, 142.97931034482758, 143.98620689655172, 144.99310344827586, 146.0], "y": [-0.25166666666666665, -0.006435185185185187, -0.2351076285548942, -0.04927695069158484, -0.05046338383838385, 0.07563852813852813, -0.1159999471426609, -0.15307407407407408, 0.06260398098633392, -0.0666540404040404, -0.07427953191401851, -0.017221230158730155, 0.030110867446393755, 0.06623809523809522, -0.01405458576511208, -0.053756046982595104, 0.03285590277777778, -0.16822279744065458, -0.2811704441391942, -0.17665911175973548, -0.09274596865074673, -0.0306353214686548, -0.10935580883138546, -0.140940475084811, -0.20116969945213314, -0.15784301881140098, -0.1010523313492063, -0.1595511282515251, -0.1025307345160 ...

# %%
star=[1, 2, 3, 4, 5]
fig=go.Figure()
avg_subjectivity=[]
for i in range(len(star)):    
    rest_5=restaurant[restaurant['stars']==star[i]]
    a=list(set(rest_5['business_id']))
    hhh=[]
    for j in progressbar.progressbar(range(len(a))):
        b=list(review[review['business_id']==a[j]]['text'])
        subjectivity=[]
        for sentence in b:
            blob = TextBlob(sentence)
            subjectivity.append(blob.sentiment.subjectivity)
            #print(subjectivity)
        if len(subjectivity)!=0:
            hhh.append(sum(subjectivity)/len(subjectivity))
    avg_subjectivity.append(sum(hhh)/len(hhh))
    trace=go.Scatter(x=np.linspace(0,len(hhh),num=len(hhh)),y=hhh,line_shape='spline',name='star{}'.format(str(star[i])))
    fig.add_trace(trace)
    fig.update_layout(title="subjectivity of different star rate",xaxis_title='review number',yaxis_title='subjectivity')
fig
# Out:
# 100% (146 of 146) |######################| Elapsed Time: 0:00:23 Time:  0:00:23
# 100% (1524 of 1524) |####################| Elapsed Time: 0:04:24 Time:  0:04:24
# 100% (3424 of 3424) |####################| Elapsed Time: 0:11:58 Time:  0:11:58
# 100% (5929 of 5929) |####################| Elapsed Time: 0:27:39 Time:  0:27:39
# 100% (603 of 603) |######################| Elapsed Time: 0:01:50 Time:  0:01:50
# <div>                            <div id="9302e513-4504-4c48-af75-42250c98c7fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9302e513-4504-4c48-af75-42250c98c7fc")) {                    Plotly.newPlot(                        "9302e513-4504-4c48-af75-42250c98c7fc",                        [{"line": {"shape": "spline"}, "name": "star1", "type": "scatter", "x": [0.0, 1.006896551724138, 2.013793103448276, 3.020689655172414, 4.027586206896552, 5.0344827586206895, 6.041379310344828, 7.048275862068966, 8.055172413793104, 9.062068965517241, 10.068965517241379, 11.075862068965517, 12.082758620689656, 13.089655172413794, 14.096551724137932, 15.10344827586207, 16.110344827586207, 17.117241379310347, 18.124137931034483, 19.131034482758622, 20.137931034482758, 21.144827586206898, 22.151724137931033, 23.158620689655173, 24.165
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(all_reviews) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.title("wordcloud star 1")
plt.imshow(wordcloud)
# Out:
# 100% (146 of 146) |######################| Elapsed Time: 0:00:22 Time:  0:00:22

# %%
stopwords = set(STOPWORDS) 
stopwords
rest_5=restaurant[restaurant['stars']==star[1]]
a=list(set(rest_5['business_id']))
all_reviews=""
for i in progressbar.progressbar(range(len(a))):
    b=list(review[review['business_id']==a[i]]['text'])
    bs=""
    for s in b:
        bs+=s
    all_reviews+=bs
replace=["food","order","location","place","McDonald","one","time","go","minute","manager","said","pizza","employee","drive thru"];
for s in replace:
    all_reviews=all_reviews.replace(s,"")
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(all_reviews) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.title("wordcloud star 2")
plt.imshow(wordcloud)
# Out:
# 100% (1524 of 1524) |####################| Elapsed Time: 0:04:12 Time:  0:04:12

# %%
stopwords = set(STOPWORDS) 
stopwords
rest_5=restaurant[restaurant['stars']==star[4]]
a=list(set(rest_5['business_id']))
all_reviews=""
for i in progressbar.progressbar(range(len(a))):
    b=list(review[review['business_id']==a[i]]['text'])
    bs=""
    for s in b:
        bs+=s
    all_reviews+=bs
replace=["food","order","location","place","McDonald","one","time","go","minute","manager","said","pizza","employee","drive thru"];
for s in replace:
    all_reviews=all_reviews.replace(s,"")
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(all_reviews) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.title("wordcloud star 5")
plt.imshow(wordcloud)
# Out:
# 100% (603 of 603) |######################| Elapsed Time: 0:01:36 Time:  0:01:36

# %%
stopwords = set(STOPWORDS) 
stopwords
rest_5=restaurant[restaurant['stars']==star[2]]
a=list(set(rest_5['business_id']))
all_reviews=""
for i in progressbar.progressbar(range(len(a))):
    b=list(review[review['business_id']==a[i]]['text'])
    bs=""
    for s in b:
        bs+=s
    all_reviews+=bs
replace=["food","order","location","place","McDonald","one","time","go","minute","manager","said","pizza","employee","drive thru"];
for s in replace:
    all_reviews=all_reviews.replace(s,"")
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(all_reviews) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.title("wordcloud star 3")
plt.imshow(wordcloud)
# Out:
# 100% (3424 of 3424) |####################| Elapsed Time: 0:12:37 Time:  0:12:37

# %%
stopwords = set(STOPWORDS) 
stopwords
rest_5=restaurant[restaurant['stars']==star[3]]
a=list(set(rest_5['business_id']))
all_reviews=""
for i in progressbar.progressbar(range(len(a))):
    b=list(review[review['business_id']==a[i]]['text'])
    bs=""
    for s in b:
        bs+=s
    all_reviews+=bs
replace=["food","order","location","place","McDonald","one","time","go","minute","manager","said","pizza","employee","drive thru"];
for s in replace:
    all_reviews=all_reviews.replace(s,"")
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(all_reviews) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.title("wordcloud star 4")
plt.imshow(wordcloud)
# Out:
# 100% (5929 of 5929) |####################| Elapsed Time: 0:42:12 Time:  0:42:12
